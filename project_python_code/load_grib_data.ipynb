# %%
import xarray as xr
import numpy as np
import netCDF4 as nc
from matplotlib import pyplot as plt

# %%
# ds = xr.open_dataset("/mnt/data1/kv30/MRMS_PrecipRate_00.00_20111231-223000.grib2", engine="pynio")

images = np.load("/mnt/data1/kv30/yl_npy_files/nexrad_min_0.2_contextual_crops/precip_f235_c66.npy")

# %%
images.shape
# Out:
# (256, 256)

# %%
plt.figure()
plt.imshow(images)
plt.show()
